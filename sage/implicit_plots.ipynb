# %%
A = vector((-1, 0))

# %%
B = vector((1, 0))

# %%
x, y = var('x y')

# %%
A - vector((x, y))
# Out:
# (-x - 1, -y)

# %%
implicit_plot(abs(A - vector((x,y))) - abs(B-vector((x,y))) - 0.5, (x, -3, 3), (y, -3, 3)) + point(A) + point(B)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
implicit_plot(abs(A - vector((x,y))) + abs(B-vector((x,y))) - 5, (x, -3, 3), (y, -3, 3)) + point(A) + point(B)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
implicit_plot(abs(A - vector((x,y)))/abs(B-vector((x,y))) - 2, (x, -3, 3), (y, -3, 3)) + point(A) + point(B)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
implicit_plot(abs(A - vector((x,y)))*abs(B-vector((x,y))) - 1, (x, -2, 2), (y, -2, 2)) + point(A) + point(B)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
G = Graphics()

# %%
counter = 0

# %%
for c in colors.keys():
    G+=implicit_plot(abs(A - vector((x,y)))*abs(B-vector((x,y))) - (0.1 + counter*0.02) , (x, -2, 2), (y, -2, 2), color = c)
    counter += 1

# %%
G
# Out:
# Graphics object consisting of 148 graphics primitives
