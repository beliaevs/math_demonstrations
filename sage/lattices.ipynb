# %%
S4=SymmetricGroup(4)

# %%
S4.subgroups()
# Out:
# [Subgroup generated by [()] of (Symmetric group of order 4! as a permutation group),
#  Subgroup generated by [(1,2)(3,4)] of (Symmetric group of order 4! as a permutation group),
#  Subgroup generated by [(1,3)(2,4)] of (Symmetric group of order 4! as a permutation group),
#  Subgroup generated by [(1,4)(2,3)] of (Symmetric group of order 4! as a permutation group),
#  Subgroup generated by [(3,4)] of (Symmetric group of order 4! as a permutation group),
#  Subgroup generated by [(2,3)] of (Symmetric group of order 4! as a permutation group),
#  Subgroup generated by [(2,4)] of (Symmetric group of order 4! as a permutation group),
#  Subgroup generated by [(1,2)] of (Symmetric group of order 4! as a permutation group),
#  Subgroup generated by [(1,3)] of (Symmetric group of order 4! as a permutation group),
#  Subgroup generated by [(1,4)] of (Symmetric group of order 4! as a permutation group),
# ...

# %%
S4_subgroups = S4.subgroups()

# %%
S4_poset = Poset((S4_subgroups, type(S4_subgroups[0]).is_subgroup))

# %%
graph = S4_poset.hasse_diagram()

# %%
graph.plot(vertex_size=2000, figsize=20, layout='acyclic' ,vertex_labels=alllabels)
# Out:
# Graphics object consisting of 97 graphics primitives

# %%
S4.order()
# Out:
# 24

# %%
alllabels=dict([(g, g.order()) for g in S4_subgroups])

# %%
alllabels
# Out:
# {Subgroup generated by [()] of (Symmetric group of order 4! as a permutation group): 1,
#  Subgroup generated by [(1,2)(3,4)] of (Symmetric group of order 4! as a permutation group): 2,
#  Subgroup generated by [(1,3)(2,4)] of (Symmetric group of order 4! as a permutation group): 2,
#  Subgroup generated by [(1,4)(2,3)] of (Symmetric group of order 4! as a permutation group): 2,
#  Subgroup generated by [(3,4)] of (Symmetric group of order 4! as a permutation group): 2,
#  Subgroup generated by [(2,3)] of (Symmetric group of order 4! as a permutation group): 2,
#  Subgroup generated by [(2,4)] of (Symmetric group of order 4! as a permutation group): 2,
#  Subgroup generated by [(1,2)] of (Symmetric group of order 4! as a permutation group): 2,
#  Subgroup generated by [(1,3)] of (Symmetric group of order 4! as a permutation group): 2,
#  Subgroup generated by [(1,4)] of (Symmetric group of order 4! as a permutation group): 2,
# ...

# %%
alllabels[S4_subgroups[1]]
# Out:
# 2
