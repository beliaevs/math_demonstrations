# %%
p = Posets(5)

# %%
len(p)
# Out:
# 63

# %%
a = p[0]

# %%
for d in p:
    if a.hasse_diagram().num_edges() < d.hasse_diagram().num_edges():
        a = d

# %%
a.show()
# Out:
# Graphics object consisting of 12 graphics primitives

# %%
posets.DivisorLattice(150).show()
# Out:
# Graphics object consisting of 33 graphics primitives

# %%
posets.TamariLattice(3).show(figsize = 20)
# Out:
# Graphics object consisting of 11 graphics primitives
